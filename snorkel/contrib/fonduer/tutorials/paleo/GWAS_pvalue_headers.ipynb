# %% [markdown]
# # Tutorial: Extracting Formation Measurements from Paleontology Literature

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import sys
import json

PARALLEL = 1
os.environ['SNORKELDB'] = 'sqlite:///gwas_nature'

# %%
from snorkel.contrib.fonduer import SnorkelSession

session = SnorkelSession()

# %%
from snorkel.contrib.fonduer.models import candidate_subclass

Pvalue = candidate_subclass('Pvalue', ['pvalue'])

# %%
from snorkel.contrib.fonduer import HTMLPreprocessor, OmniParser

docs_path = os.environ['DATA'] + '/gwas/db/papers'

max_docs = 30
doc_preprocessor = HTMLPreprocessor(docs_path, max_docs=max_docs)

# %%
corpus_parser = OmniParser(structural=True, lingual=True, visual=False)
# %time corpus_parser.apply(doc_preprocessor, parallelism=PARALLEL)
# Out:
# Clearing existing...
# Running UDF...
# CPU times: user 1min 43s, sys: 5.26 s, total: 1min 48s
# Wall time: 4min 27s

# %%
from snorkel.contrib.fonduer.models import Document, Phrase

print "Documents:", session.query(Document).count()
print "Phrases:", session.query(Phrase).count()
# Out:
# Documents: 30
# Phrases: 66728

# %%
docs = session.query(Document).order_by(Document.name).all()

# %%
from snorkel.matchers import RegexMatchSpan, Union

# p-value matcher
rgx1 = u'[1-9]\d?[\xb7\.]?\d*[\s\u2009]*[\xd7\xb7\*][\s\u2009]*10[\s\u2009]*[-\u2212\u2013\u2012][\s\u2009]*\d+'
pval_rgx_matcher1 = RegexMatchSpan(rgx=rgx1)
rgx2 = u'[1-9]\d?[\xb7\.]?\d*[\s\u2009]*[eE][\s\u2009]*[-\u2212\u2013\u2012][\s\u2009]*\d+'
pval_rgx_matcher2 = RegexMatchSpan(rgx=rgx2)
rgx3 = u'0\.0000+\d+'
pval_rgx_matcher3 = RegexMatchSpan(rgx=rgx3)
pval_rgx_matcher = Union(pval_rgx_matcher1, pval_rgx_matcher2, pval_rgx_matcher3)

# %%
from snorkel.contrib.fonduer.fonduer.candidates import OmniNgrams

heptagrams = OmniNgrams(n_max=7, split_tokens=[])

# %%
from snorkel.contrib.fonduer.candidates import CandidateExtractor

candidate_extractor = CandidateExtractor(Pvalue, [heptagrams], [pval_rgx_matcher])

# %time candidate_extractor.apply(docs, split=0, parallelism=PARALLEL)
# Out:
# Clearing existing...
# Running UDF...
# [========================================] 100%
# CPU times: user 32.2 s, sys: 633 ms, total: 32.8 s
# Wall time: 32.4 s

# %% [markdown]
# Here we specified that these `Candidates` belong to the training set by specifying `split=0`; recall that we're referring to train/dev/test as splits 0/1/2.

# %%
candidates = session.query(Pvalue).filter(Pvalue.split == 0).all()
print "Number of candidates:", len(candidates)
# Out:
# Number of candidates: 763

# %%
import re

pvalue_rgx = u'{}|{}|{}'.format(rgx1, rgx2, rgx3)
pvalue_matcher = re.compile(pvalue_rgx, flags=(re.I|re.UNICODE))

def overlap(a1, b1, a2, b2):
    return not (b1 < a2 or a1 > b2)


def extract_metadata(phrase):
    return [p.text.encode('utf-8') for p in phrase.table.phrases if 
        p.row_end <= 2 and
        overlap(p.col_start, p.col_end, phrase.col_start, phrase.col_end) and 
        not pvalue_matcher.match(p.text)]


def make_line(phrase): 
    doc_id = phrase.document.name
    table_idx = phrase.table.position + 1 # make table_idx 1-indexed
    row = phrase.row_start
    col = phrase.col_start
    pvalue = c[0].get_span().ljust(10) # pad for uniform width
    metadata = extract_metadata(phrase)
#     print('{}: {}\t{}'.format(doc_id, pvalue, metadata))
    line = map(lambda x: unicode(x).encode('utf-8'), [doc_id, table_idx, row, col, pvalue, metadata])
    return line

# %%
import csv

OUTFILE = 'pvalue_metadata.tsv'

with open(OUTFILE, 'wb') as csvfile:
    writer = csv.writer(csvfile, delimiter='\t', quoting=csv.QUOTE_MINIMAL)
    writer.writerow(["doc_id", "table_index", "rows", "cols", "p-value", "metadata"])
    for c in candidates:
        phrase = c.get_parent()
        if not phrase.table:
            continue
        line = make_line(phrase)
        print(line)
        writer.writerow(line)
# Out:
# ['18604267', '1', '19', '12', '2.1E-12   ', "['Combined', 'P-Value']"]
# ['18604267', '1', '12', '12', '4.8E-25   ', "['Combined', 'P-Value']"]
# ['18604267', '1', '16', '12', '3.6E-23   ', "['Combined', 'P-Value']"]
# ['18604267', '4', '2', '5', '1.7E-95   ', "['P-Value']"]
# ['18604267', '2', '3', '11', '2.0E-16   ', "['Combined', 'c', 'P-Value', '<2.0E-16']"]
# ['18604267', '1', '16', '10', '3.2E-07   ', "['WGHS-2', 'P-Value']"]
# ['18604267', '1', '18', '10', '5.2E-06   ', "['WGHS-2', 'P-Value']"]
# ['18604267', '1', '7', '12', '5.1E-29   ', "['Combined', 'P-Value']"]
# ['18604267', '2', '3', '7', '2.0E-16   ', "['WGHS-1', 'c', 'P-Value', '<2.0E-16']"]
# ['18604267', '1', '14', '10', '2.7E-07   ', "['WGHS-2', 'P-Value']"]
# ['18604267', '1', '13', '8', '5.7E-17   ', "['WGHS-1', 'P-Value']"]
# ['18604267', '2', '4', '7', '1.3E-08   ', "['WGHS-1', 'c', 'P-Value', '<2.0E-16']"]
# ['18604267', '1', '14', '12', '5.9E-23   ', "['Combined', 'P-Value']"]
# ['18604267', '1', '15', '10', '4.9E-05   ', "['WGHS-2', 'P-Value']"]
# ['18604267', '1', '9', '12', '3.1E-11   ', "['Combined', 'P-Value']"]
# ['18604267', '1', '10', '10', '4.3E-05   ', "['WGHS-2', 'P-Value']"]
# ['18604267', '1', '10', '8', '4.4E-15   ', "['WGHS-1', 'P-Value']"]
# ['18604267', '2', '2', '9', '2.0E-16   ', "['WGHS-2', 'c', 'P-Value', '<2.0E-16']"]
# ['18604267', '1', '2', '12', '1.3E-16   ', "['Combined', 'P-Value']"]
# ['18604267', '2', '5', '9', '1.9E-10   ', "['WGHS-2', 'c', 'P-Value', '<2.0E-16']"]
# ['18604267', '2', '5', '11', '2.0E-16   ', "['Combined', 'c', 'P-Value', '<2.0E-16']"]
# ['18604267', '1', '19', '8', '3.2E-08   ', "['WGHS-1', 'P-Value']"]
# ['18604267', '1', '9', '10', '7.5E-03   ', "['WGHS-2', 'P-Value']"]
# ['18604267', '1', '8', '8', '4.4E-12   ', "['WGHS-1', 'P-Value']"]
# ['18604267', '1', '13', '10', '7.9E-07   ', "['WGHS-2', 'P-Value']"]
# ['18604267', '1', '7', '8', '1.1E-20   ', "['WGHS-1', 'P-Value']"]
# ['18604267', '2', '3', '9', '2.0E-16   ', "['WGHS-2', 'c', 'P-Value', '<2.0E-16']"]
# ['18604267', '1', '18', '8', '1.2E-08   ', "['WGHS-1', 'P-Value']"]
# ['18604267', '1', '4', '12', '1.5E-14   ', "['Combined', 'P-Value']"]
# ['18604267', '2', '2', '11', '2.0E-16   ', "['Combined', 'c', 'P-Value', '<2.0E-16']"]
# ['18604267', '1', '3', '12', '1.7E-16   ', "['Combined', 'P-Value']"]
# ['18604267', '1', '4', '8', '1.7E-10   ', "['WGHS-1', 'P-Value']"]
# ['18604267', '1', '5', '10', '2.4E-05   ', "['WGHS-2', 'P-Value']"]
# ['18604267', '1', '11', '8', '2.1E-28   ', "['WGHS-1', 'P-Value']"]
# ['18604267', '1', '17', '12', '3.1E-11   ', "['Combined', 'P-Value']"]
# ['18604267', '1', '20', '12', '6.3E-10   ', "['Combined', 'P-Value']"]
# ['18604267', '1', '11', '12', '3.6E-47   ', "['Combined', 'P-Value']"]
# ['18604267', '1', '5', '8', '5.0E-10   ', "['WGHS-1', 'P-Value']"]
# ['18604267', '1', '19', '10', '8.6E-06   ', "['WGHS-2', 'P-Value']"]
# ['18604267', '1', '2', '8', '1.3E-11   ', "['WGHS-1', 'P-Value']"]
# ['18604267', '1', '7', '10', '5.9E-10   ', "['WGHS-2', 'P-Value']"]
# ['18604267', '1', '10', '12', '1.3E-18   ', "['Combined', 'P-Value']"]
# ['18604267', '1', '12', '10', '1.2E-07   ', "['WGHS-2', 'P-Value']"]
# ['18604267', '1', '8', '10', '2.6E-04   ', "['WGHS-2', 'P-Value']"]
# ['18604267', '1', '2', '10', '1.4E-06   ', "['WGHS-2', 'P-Value']"]
# ['18604267', '2', '2', '7', '2.0E-16   ', "['WGHS-1', 'c', 'P-Value', '<2.0E-16']"]
# ['18604267', '1', '16', '8', '1.9E-17   ', "['WGHS-1', 'P-Value']"]
# ['18604267', '1', '8', '12', '5.4E-15   ', "['Combined', 'P-Value']"]
# ['18604267', '1', '15', '8', '7.2E-13   ', "['WGHS-1', 'P-Value']"]
# ['18604267', '2', '4', '9', '5.1E-03   ', "['WGHS-2', 'c', 'P-Value', '<2.0E-16']"]
# ['18604267', '1', '15', '12', '1.5E-16   ', "['Combined', 'P-Value']"]
# ['18604267', '1', '11', '10', '1.3E-21   ', "['WGHS-2', 'P-Value']"]
# ['18604267', '2', '4', '11', '3.2E-10   ', "['Combined', 'c', 'P-Value', '<2.0E-16']"]
# ['18604267', '1', '12', '8', '6.2E-19   ', "['WGHS-1', 'P-Value']"]
# ['18604267', '4', '3', '5', '3.0E-78   ', "['P-Value']"]
# ['18604267', '1', '6', '12', '9.2E-17   ', "['Combined', 'P-Value']"]
# ['18604267', '1', '20', '8', '2.7E-08   ', "['WGHS-1', 'P-Value']"]
# ['18604267', '2', '5', '7', '2.0E-16   ', "['WGHS-1', 'c', 'P-Value', '<2.0E-16']"]
# ['18604267', '1', '6', '8', '4.5E-12   ', "['WGHS-1', 'P-Value']"]
# ['18604267', '1', '13', '12', '2.5E-22   ', "['Combined', 'P-Value']"]
# ['18604267', '1', '5', '12', '6.1E-14   ', "['Combined', 'P-Value']"]
# ['18604267', '1', '14', '8', '3.7E-17   ', "['WGHS-1', 'P-Value']"]
# ['18604267', '1', '3', '10', '3.5E-06   ', "['WGHS-2', 'P-Value']"]
# ['18604267', '1', '17', '10', '7.7E-04   ', "['WGHS-2', 'P-Value']"]
# ['18604267', '1', '17', '8', '1.0E-08   ', "['WGHS-1', 'P-Value']"]
# ['18604267', '1', '9', '8', '7.9E-10   ', "['WGHS-1', 'P-Value']"]
# ['18604267', '1', '20', '10', '5.8E-03   ', "['WGHS-2', 'P-Value']"]
# ['18604267', '1', '6', '10', '3.2E-06   ', "['WGHS-2', 'P-Value']"]
# ['18604267', '4', '4', '5', '5.3E-37   ', "['P-Value']"]
# ['18604267', '1', '4', '10', '1.5E-05   ', "['WGHS-2', 'P-Value']"]
# ['18604267', '1', '19', '6', '0.00007   ', "['HW', 'b', '0.08']"]
# ['18604267', '1', '18', '12', '3.9E-13   ', "['Combined', 'P-Value']"]
# ['18604267', '1', '3', '8', '8.2E-12   ', "['WGHS-1', 'P-Value']"]
# ['20041166', '2', '11', '3', '9.3E-01   ', "['Model with HLA allele, rs2395029, rs9264942']"]
# ['20041166', '3', '23', '10', '8.5E-01   ', "['p progression']"]
# ['20041166', '2', '13', '4', '7.8E-01   ', "['Model with HLA allele, rs2395029, rs9264942, rs259919, rs9468692, rs9266409, rs8192591']"]
# ['20041166', '3', '28', '10', '2.0E-01   ', "['p progression']"]
# ['20041166', '2', '15', '4', '2.5E-01   ', "['Model with HLA allele, rs2395029, rs9264942, rs259919, rs9468692, rs9266409, rs8192591']"]
# ['20041166', '2', '2', '2', '2.7E-02   ', "['Model with HLA allele, rs2395029']"]
# ['20041166', '3', '1', '8', '1.7E-10   ', "['p setpoint']"]
# ['20041166', '2', '11', '1', '5.0E-03   ', "['Model with HLA allele only']"]
# ['20041166', '2', '1', '1', '3.4E-02   ', "['Model with HLA allele only']"]
# ['20041166', '2', '12', '3', '7.1E-01   ', "['Model with HLA allele, rs2395029, rs9264942']"]
# ['20041166', '3', '14', '8', '7.7E-01   ', "['p setpoint']"]
# ['20041166', '3', '18', '10', '9.3E-01   ', "['p progression']"]
# ['20041166', '2', '15', '1', '1.2E-02   ', "['Model with HLA allele only']"]
# ['20041166', '3', '18', '8', '7.3E-01   ', "['p setpoint']"]
# ['20041166', '2', '14', '4', '9.5E-01   ', "['Model with HLA allele, rs2395029, rs9264942, rs259919, rs9468692, rs9266409, rs8192591']"]
# ['20041166', '1', '1', '3', '9.4E-12   ', "['P-value (initial, N = 486)']"]
# ['20041166', '2', '1', '3', '1.1E-01   ', "['Model with HLA allele, rs2395029, rs9264942']"]
# ['20041166', '2', '10', '2', '2.5E-04   ', "['Model with HLA allele, rs2395029']"]
# ['20041166', '2', '10', '1', '1.0E-03   ', "['Model with HLA allele only']"]
# ['20041166', '1', '2', '7', '5.9E-32   ', "['P-value (all, N = 2362)']"]
# ['20041166', '2', '14', '2', '6.3E-02   ', "['Model with HLA allele, rs2395029']"]
# ['20041166', '3', '17', '10', '5.2E-01   ', "['p progression']"]
# ['20041166', '3', '6', '8', '2.9E-01   ', "['p setpoint']"]
# ['20041166', '1', '1', '7', '4.5E-35   ', "['P-value (all, N = 2362)']"]
# ['20041166', '2', '14', '3', '9.9E-01   ', "['Model with HLA allele, rs2395029, rs9264942']"]
# ['20041166', '3', '20', '10', '1.2E-01   ', "['p progression']"]
# ['20041166', '2', '4', '1', '7.0E-03   ', "['Model with HLA allele only']"]
# ['20041166', '2', '13', '1', '5.4E-04   ', "['Model with HLA allele only']"]
# ['20041166', '3', '17', '8', '3.2E-01   ', "['p setpoint']"]
# ['20041166', '2', '1', '4', '9.9E-01   ', "['Model with HLA allele, rs2395029, rs9264942, rs259919, rs9468692, rs9266409, rs8192591']"]
# ['20041166', '3', '2', '8', '7.5E-05   ', "['p setpoint']"]
# ['20041166', '3', '22', '8', '4.3E-01   ', "['p setpoint']"]
# ['20041166', '3', '3', '10', '1.5E-01   ', "['p progression']"]
# ['20041166', '2', '10', '4', '5.0E-02   ', "['Model with HLA allele, rs2395029, rs9264942, rs259919, rs9468692, rs9266409, rs8192591']"]
# ['20041166', '2', '3', '3', '6.0E-03   ', "['Model with HLA allele, rs2395029, rs9264942']"]
# ['20041166', '3', '22', '10', '9.0E-01   ', "['p progression']"]
# ['20041166', '2', '2', '1', '2.8E-02   ', "['Model with HLA allele only']"]
# ['20041166', '2', '1', '2', '6.9E-02   ', "['Model with HLA allele, rs2395029']"]
# ['20041166', '3', '14', '10', '1.4E-01   ', "['p progression']"]
# ['20041166', '3', '28', '8', '7.9E-01   ', "['p setpoint']"]
# ['20041166', '3', '15', '8', '7.9E-01   ', "['p setpoint']"]
# ['20041166', '2', '13', '3', '1.8E-01   ', "['Model with HLA allele, rs2395029, rs9264942']"]
# ['20041166', '3', '19', '8', '9.0E-01   ', "['p setpoint']"]
# ['20041166', '2', '4', '2', '1.5E-02   ', "['Model with HLA allele, rs2395029']"]
# ['20041166', '1', '2', '3', '3.8E-09   ', "['P-value (initial, N = 486)']"]
# ['20041166', '1', '1', '5', '4.2E-23   ', "['P-value (replication, N = 1896)']"]
# ['20041166', '3', '15', '10', '1.9E-01   ', "['p progression']"]
# ['20041166', '3', '10', '8', '3.4E-01   ', "['p setpoint']"]
# ['20041166', '2', '2', '4', '3.2E-01   ', "['Model with HLA allele, rs2395029, rs9264942, rs259919, rs9468692, rs9266409, rs8192591']"]
# ['20041166', '2', '12', '2', '4.9E-02   ', "['Model with HLA allele, rs2395029']"]
# ['20041166', '2', '15', '3', '1.6E-01   ', "['Model with HLA allele, rs2395029, rs9264942']"]
# ['20041166', '3', '29', '8', '5.1E-01   ', "['p setpoint']"]
# ['20041166', '3', '13', '8', '6.0E-01   ', "['p setpoint']"]
# ['20041166', '3', '1', '10', '3.5E-07   ', "['p progression']"]
# ['20041166', '2', '12', '4', '7.8E-01   ', "['Model with HLA allele, rs2395029, rs9264942, rs259919, rs9468692, rs9266409, rs8192591']"]
# ['20041166', '2', '3', '4', '2.9E-02   ', "['Model with HLA allele, rs2395029, rs9264942, rs259919, rs9468692, rs9266409, rs8192591']"]
# ['20041166', '2', '2', '3', '1.2E-01   ', "['Model with HLA allele, rs2395029, rs9264942']"]
# ['20041166', '2', '14', '1', '3.4E-02   ', "['Model with HLA allele only']"]
# ['20041166', '3', '13', '10', '6.3E-01   ', "['p progression']"]
# ['20041166', '2', '11', '4', '8.5E-01   ', "['Model with HLA allele, rs2395029, rs9264942, rs259919, rs9468692, rs9266409, rs8192591']"]
# ['20041166', '2', '3', '2', '1.0E-03   ', "['Model with HLA allele, rs2395029']"]
# ['20041166', '2', '15', '2', '2.0E-03   ', "['Model with HLA allele, rs2395029']"]
# ['20041166', '2', '13', '2', '3.0E-03   ', "['Model with HLA allele, rs2395029']"]
# ['20041166', '2', '10', '3', '6.0E-02   ', "['Model with HLA allele, rs2395029, rs9264942']"]
# ['20041166', '3', '24', '8', '6.5E-01   ', "['p setpoint']"]
# ['20041166', '2', '7', '4', '3.0E-03   ', "['Model with HLA allele, rs2395029, rs9264942, rs259919, rs9468692, rs9266409, rs8192591']"]
# ['20041166', '2', '9', '2', '7.8E-02   ', "['Model with HLA allele, rs2395029']"]
# ['20041166', '3', '4', '10', '6.0E-01   ', "['p progression']"]
# ['20041166', '3', '29', '10', '6.0E-01   ', "['p progression']"]
# ['20041166', '2', '4', '3', '4.3E-01   ', "['Model with HLA allele, rs2395029, rs9264942']"]
# ['20041166', '2', '4', '4', '3.8E-01   ', "['Model with HLA allele, rs2395029, rs9264942, rs259919, rs9468692, rs9266409, rs8192591']"]
# ['20041166', '3', '5', '10', '8.2E-01   ', "['p progression']"]
# ['20041166', '3', '24', '10', '7.9E-01   ', "['p progression']"]
# ['20041166', '3', '19', '10', '8.3E-01   ', "['p progression']"]
# ['20041166', '3', '6', '10', '2.3E-01   ', "['p progression']"]
# ['20041166', '2', '9', '4', '1.2E-01   ', "['Model with HLA allele, rs2395029, rs9264942, rs259919, rs9468692, rs9266409, rs8192591']"]
# ['20041166', '3', '12', '8', '1.9E-01   ', "['p setpoint']"]
# ['20041166', '2', '3', '1', '5.0E-03   ', "['Model with HLA allele only']"]
# ['20041166', '3', '3', '8', '8.1E-03   ', "['p setpoint']"]
# ['20041166', '3', '26', '8', '5.0E-01   ', "['p setpoint']"]
# ['20041166', '2', '5', '1', '7.0E-03   ', "['Model with HLA allele only']"]
# ['20041166', '3', '20', '8', '9.2E-01   ', "['p setpoint']"]
# ['20041166', '3', '26', '10', '9.3E-01   ', "['p progression']"]
# ['20041166', '3', '9', '10', '9.2E-01   ', "['p progression']"]
# ['20041166', '2', '7', '2', '4.9E-06   ', "['Model with HLA allele, rs2395029']"]
# ['20041166', '3', '21', '10', '2.9E-01   ', "['p progression']"]
# ['20041166', '2', '8', '1', '1.9E-05   ', "['Model with HLA allele only']"]
# ['20041166', '2', '6', '3', '1.2E-02   ', "['Model with HLA allele, rs2395029, rs9264942']"]
# ['20041166', '2', '8', '3', '6.2E-04   ', "['Model with HLA allele, rs2395029, rs9264942']"]
# ['20041166', '3', '21', '8', '4.5E-01   ', "['p setpoint']"]
# ['20041166', '3', '27', '10', '7.0E-02   ', "['p progression']"]
# ['20041166', '2', '5', '2', '3.3E-02   ', "['Model with HLA allele, rs2395029']"]
# ['20041166', '3', '9', '8', '8.6E-01   ', "['p setpoint']"]
# ['20041166', '2', '6', '1', '2.0E-03   ', "['Model with HLA allele only']"]
# ['20041166', '3', '11', '10', '1.4E-01   ', "['p progression']"]
# ['20041166', '3', '5', '8', '6.0E-01   ', "['p setpoint']"]
# ['20041166', '3', '11', '8', '6.5E-02   ', "['p setpoint']"]
# ['20041166', '2', '6', '4', '1.6E-02   ', "['Model with HLA allele, rs2395029, rs9264942, rs259919, rs9468692, rs9266409, rs8192591']"]
# ['20041166', '2', '7', '1', '5.2E-05   ', "['Model with HLA allele only']"]
# ['20041166', '3', '4', '8', '1.5E-01   ', "['p setpoint']"]
# ['20041166', '2', '8', '4', '2.0E-03   ', "['Model with HLA allele, rs2395029, rs9264942, rs259919, rs9468692, rs9266409, rs8192591']"]
# ['20041166', '3', '23', '8', '5.5E-01   ', "['p setpoint']"]
# ['20041166', '2', '9', '3', '1.9E-01   ', "['Model with HLA allele, rs2395029, rs9264942']"]
# ['20041166', '2', '7', '3', '2.0E-03   ', "['Model with HLA allele, rs2395029, rs9264942']"]
# ['20041166', '3', '2', '10', '3.8E-04   ', "['p progression']"]
# ['20041166', '3', '10', '10', '6.3E-01   ', "['p progression']"]
# ['20041166', '2', '12', '1', '1.2E-11   ', "['Model with HLA allele only']"]
# ['20041166', '2', '5', '4', '2.4E-01   ', "['Model with HLA allele, rs2395029, rs9264942, rs259919, rs9468692, rs9266409, rs8192591']"]
# ['20041166', '3', '12', '10', '2.5E-01   ', "['p progression']"]
# ['20041166', '2', '9', '1', '4.2E-02   ', "['Model with HLA allele only']"]
# ['20041166', '2', '8', '2', '3.9E-05   ', "['Model with HLA allele, rs2395029']"]
# ['20041166', '2', '11', '2', '3.0E-02   ', "['Model with HLA allele, rs2395029']"]
# ['20041166', '2', '5', '3', '5.8E-01   ', "['Model with HLA allele, rs2395029, rs9264942']"]
# ['20041166', '2', '6', '2', '2.1E-04   ', "['Model with HLA allele, rs2395029']"]
# ['20041166', '1', '2', '5', '1.6E-23   ', "['P-value (replication, N = 1896)']"]
# ['20041166', '3', '27', '8', '1.1E-01   ', "['p setpoint']"]
# ['20305777', '2', '12', '6', '2.45 E-06 ', "['P', 'b']"]
# ['20305777', '2', '4', '6', '3.07 E-03 ', "['P', 'b']"]
# ['20305777', '3', '2', '5', '1.48 E-8  ', "['Haplotype effect', 'b', 'P value']"]
# ['20305777', '3', '3', '5', '5.07 E-8  ', "['Haplotype effect', 'b', 'P value']"]
# ['20305777', '2', '13', '6', '5.74 E-03 ', "['P', 'b']"]
# ['20305777', '2', '3', '6', '1.38 E-06 ', "['P', 'b']"]
# ['20305777', '2', '14', '6', '6.73 E-08 ', "['P', 'b']"]
# ['20305777', '2', '5', '6', '2.43 E-08 ', "['P', 'b']"]
# ['20305777', '2', '19', '6', '5.10 E-09 ', "['P', 'b']"]
# ['20395239', '2', '7', '11', '1.3E - 02 ', "['UK', 'P', '-value']"]
# ['20395239', '2', '3', '8', '6.2E - 10 ', "['Australia', 'P', '-value']"]
# ['20395239', '2', '15', '12', '4.6E - 07 ', "['Meta-analysis', 'P', '-value']"]
# ['20395239', '2', '13', '11', '5.5E - 03 ', "['UK', 'P', '-value']"]
# ['20395239', '2', '12', '12', '3.1E - 07 ', "['Meta-analysis', 'P', '-value']"]
# ['20395239', '2', '6', '11', '1.2E - 02 ', "['UK', 'P', '-value']"]
# ['20395239', '2', '16', '12', '4.9E - 07 ', "['Meta-analysis', 'P', '-value']"]
# ['20395239', '2', '6', '8', '2.2E - 06 ', "['Australia', 'P', '-value']"]
# ['20395239', '2', '5', '8', '1.4E - 06 ', "['Australia', 'P', '-value']"]
# ['20395239', '2', '4', '8', '2.0E - 08 ', "['Australia', 'P', '-value']"]
# ['20395239', '2', '7', '12', '1.5E - 07 ', "['Meta-analysis', 'P', '-value']"]
# ['20395239', '2', '11', '11', '3.5E - 03 ', "['UK', 'P', '-value']"]
# ['20395239', '2', '12', '8', '8.6E - 06 ', "['Australia', 'P', '-value']"]
# ['20395239', '2', '4', '12', '3.4E - 08 ', "['Meta-analysis', 'P', '-value']"]
# ['20395239', '2', '11', '8', '1.4E - 05 ', "['Australia', 'P', '-value']"]
# ['20395239', '2', '8', '11', '1.3E - 02 ', "['UK', 'P', '-value']"]
# ['20395239', '2', '5', '11', '7.6E - 03 ', "['UK', 'P', '-value']"]
# ['20395239', '2', '15', '8', '7.5E - 05 ', "['Australia', 'P', '-value']"]
# ['20395239', '2', '15', '11', '1.9E - 03 ', "['UK', 'P', '-value']"]
# ['20395239', '2', '3', '12', '3.4E - 10 ', "['Meta-analysis', 'P', '-value']"]
# ['20395239', '2', '8', '8', '2.6E - 06 ', "['Australia', 'P', '-value']"]
# ['20395239', '2', '11', '12', '2.0E - 07 ', "['Meta-analysis', 'P', '-value']"]
# ['20395239', '2', '9', '12', '1.5E - 07 ', "['Meta-analysis', 'P', '-value']"]
# ['20395239', '2', '2', '11', '3.1E - 03 ', "['UK', 'P', '-value']"]
# ['20395239', '2', '10', '8', '9.1E - 06 ', "['Australia', 'P', '-value']"]
# ['20395239', '2', '2', '12', '1.9E - 10 ', "['Meta-analysis', 'P', '-value']"]
# ['20395239', '2', '10', '11', '5.6E - 03 ', "['UK', 'P', '-value']"]
# ['20395239', '2', '6', '12', '1.2E - 07 ', "['Meta-analysis', 'P', '-value']"]
# ['20395239', '2', '13', '12', '3.4E - 07 ', "['Meta-analysis', 'P', '-value']"]
# ['20395239', '2', '2', '8', '1.6E - 08 ', "['Australia', 'P', '-value']"]
# ['20395239', '2', '4', '11', '6.7E - 02 ', "['UK', 'P', '-value']"]
# ['20395239', '2', '16', '11', '2.2E - 02 ', "['UK', 'P', '-value']"]
# ['20395239', '2', '8', '12', '1.5E - 07 ', "['Meta-analysis', 'P', '-value']"]
# ['20395239', '2', '10', '12', '1.8E - 07 ', "['Meta-analysis', 'P', '-value']"]
# ['20395239', '2', '13', '8', '1.8E - 05 ', "['Australia', 'P', '-value']"]
# ['20395239', '2', '16', '8', '5.2E - 06 ', "['Australia', 'P', '-value']"]
# ['20395239', '2', '5', '12', '3.5E - 08 ', "['Meta-analysis', 'P', '-value']"]
# ['20395239', '2', '14', '11', '5.9E - 03 ', "['UK', 'P', '-value']"]
# ['20395239', '2', '12', '11', '1.0E - 02 ', "['UK', 'P', '-value']"]
# ['20395239', '2', '3', '11', '1.3E - 02 ', "['UK', 'P', '-value']"]
# ['20395239', '2', '9', '8', '1.6E - 06 ', "['Australia', 'P', '-value']"]
# ['20395239', '2', '14', '12', '4.4E - 07 ', "['Meta-analysis', 'P', '-value']"]
# ['20395239', '2', '14', '8', '2.0E - 05 ', "['Australia', 'P', '-value']"]
# ['20395239', '2', '7', '8', '2.6E - 06 ', "['Australia', 'P', '-value']"]
# ['20395239', '2', '9', '11', '2.5E - 02 ', "['UK', 'P', '-value']"]
# ['20485516', '2', '1', '13', '1.67e-9   ', "['Meta-analysis P']"]
# ['20485516', '2', '2', '10', '4.23e-5   ', "['UK P']"]
# ['20485516', '4', '4', '13', '7.02e-9   ', "['Overall Meta-analysis', 'P']"]
# ['20485516', '2', '4', '10', '5.32e-6   ', "['UK P']"]
# ['20485516', '2', '5', '7', '3.24e-4   ', "['AU P']"]
# ['20485516', '2', '3', '13', '4.94e-8   ', "['Meta-analysis P']"]
# ['20485516', '2', '3', '10', '3.97e-5   ', "['UK P']"]
# ['20485516', '2', '1', '7', '3.66e-3   ', "['AU P']"]
# ['20485516', '4', '4', '7', '1.57e-7   ', "['Meta-analyzed Twin cohorts', 'P']"]
# ['20485516', '4', '3', '13', '4.60e-10  ', "['Overall Meta-analysis', 'P']"]
# ['20485516', '2', '2', '7', '2.82e-4   ', "['AU P']"]
# ['20485516', '2', '3', '7', '2.87e-4   ', "['AU P']"]
# ['20485516', '2', '2', '13', '4.94e-8   ', "['Meta-analysis P']"]
# ['20485516', '2', '4', '13', '1.08e-7   ', "['Meta-analysis P']"]
# ['20485516', '2', '5', '13', '1.57e-7   ', "['Meta-analysis P']"]
# ['20485516', '2', '4', '7', '2.59e-3   ', "['AU P']"]
# ['20485516', '4', '3', '10', '2.7e-4    ', "['Extended cohort (pool samples plus extra samples)', 'P', '0.014']"]
# ['20485516', '2', '1', '10', '2.87e-8   ', "['UK P']"]
# ['20485516', '2', '5', '10', '1.29e-4   ', "['UK P']"]
# ['20485516', '4', '3', '7', '4.87e-7   ', "['Meta-analyzed Twin cohorts', 'P']"]
# ['20485516', '4', '2', '13', '8.95e-11  ', "['Overall Meta-analysis', 'P']"]
# ['20485516', '4', '2', '7', '1.67e-9   ', "['Meta-analyzed Twin cohorts', 'P']"]
# ['22430674', '1', '2', '2', '4.12E-10  ', "['Global haplotype', 'P', '-value']"]
# ['22430674', '1', '2', '4', '2.6E-06   ', "['Best associated hTag-SNP', 'Single', 'P', '-value for hTag-SBP']"]
# ['22430674', '1', '4', '6', '2.4E-04   ', "['Best associated SNP within the locus', 'P', 'value_single (CNG)']"]
# ['22430674', '1', '2', '6', '2.6E-06   ', "['Best associated SNP within the locus', 'P', 'value_single (CNG)']"]
# ['22430674', '1', '6', '2', '9.51E-184 ', "['Global haplotype', 'P', '-value']"]
# ['22430674', '1', '6', '4', '5.4E-32   ', "['Best associated hTag-SNP', 'Single', 'P', '-value for hTag-SBP']"]
# ['22430674', '1', '4', '4', '1.04E-03  ', "['Best associated hTag-SNP', 'Single', 'P', '-value for hTag-SBP']"]
# ['22430674', '1', '4', '2', '3.13E-09  ', "['Global haplotype', 'P', '-value']"]
# ['22430674', '1', '6', '6', '3.32E-126 ', "['Best associated SNP within the locus', 'P', 'value_single (CNG)']"]
# ['22570697', '1', '2', '11', '8.18E-34  ', "['Meta-Analysis', '*', 'P']"]
# ['22570697', '1', '16', '11', '1.24E-07  ', "['Meta-Analysis', '*', 'P']"]
# ['22570697', '1', '13', '11', '1.36E-08  ', "['Meta-Analysis', '*', 'P']"]
# ['22570697', '1', '5', '11', '9.72E-15  ', "['Meta-Analysis', '*', 'P']"]
# ['22570697', '1', '12', '11', '9.84E-09  ', "['Meta-Analysis', '*', 'P']"]
# ['22570697', '1', '18', '11', '2.16E-07  ', "['Meta-Analysis', '*', 'P']"]
# ['22570697', '1', '14', '11', '4.76E-08  ', "['Meta-Analysis', '*', 'P']"]
# ['22570697', '1', '9', '11', '2.64E-09  ', "['Meta-Analysis', '*', 'P']"]
# ['22570697', '1', '15', '11', '1.22E-07  ', "['Meta-Analysis', '*', 'P']"]
# ['22570697', '1', '6', '11', '1.95E-11  ', "['Meta-Analysis', '*', 'P']"]
# ['22570697', '1', '7', '11', '1.44E-10  ', "['Meta-Analysis', '*', 'P']"]
# ['22570697', '1', '8', '11', '1.86E-10  ', "['Meta-Analysis', '*', 'P']"]
# ['22570697', '1', '10', '11', '3.78E-09  ', "['Meta-Analysis', '*', 'P']"]
# ['22570697', '1', '17', '11', '1.75E-07  ', "['Meta-Analysis', '*', 'P']"]
# ['22570697', '1', '4', '11', '2.01E-15  ', "['Meta-Analysis', '*', 'P']"]
# ['22570697', '1', '3', '11', '1.43E-17  ', "['Meta-Analysis', '*', 'P']"]
# ['22570697', '1', '11', '11', '8.37E-09  ', "['Meta-Analysis', '*', 'P']"]
# ['23006423', '2', '4', '6', '3.61E-05  ', "['LCL', 'Paclitaxel', 'P value']"]
# ['23006423', '2', '12', '6', '6.27E-06  ', "['LCL', 'Paclitaxel', 'P value']"]
# ['23006423', '2', '13', '8', '6.74E-05  ', "['LCL', 'Docetaxel', 'P value']"]
# ['23006423', '2', '7', '6', '7.00E-05  ', "['LCL', 'Paclitaxel', 'P value']"]
# ['23006423', '2', '13', '6', '7.76E-05  ', "['LCL', 'Paclitaxel', 'P value']"]
# ['23006423', '2', '8', '6', '6.04E-05  ', "['LCL', 'Paclitaxel', 'P value']"]
# ['23006423', '2', '3', '6', '2.71E-05  ', "['LCL', 'Paclitaxel', 'P value']"]
# ['23006423', '2', '10', '6', '5.10E-04  ', "['LCL', 'Paclitaxel', 'P value']"]
# ['23006423', '2', '12', '8', '2.46E-05  ', "['LCL', 'Docetaxel', 'P value']"]
# ['23006423', '2', '10', '8', '7.85E-04  ', "['LCL', 'Docetaxel', 'P value']"]
# ['23006423', '2', '11', '6', '6.94E-04  ', "['LCL', 'Paclitaxel', 'P value']"]
# ['23006423', '2', '6', '6', '6.36E-05  ', "['LCL', 'Paclitaxel', 'P value']"]
# ['23006423', '2', '11', '8', '3.32E-04  ', "['LCL', 'Docetaxel', 'P value']"]
# ['23006423', '2', '5', '6', '6.56E-05  ', "['LCL', 'Paclitaxel', 'P value']"]
# ['23056639', '2', '5', '8', '3.43E-02  ', "['Combined', 'Effect (se)', '-1.38E-02 (0.006)']"]
# ['23056639', '2', '6', '8', '2.33E-02  ', "['Combined', 'Effect (se)', '-1.38E-02 (0.006)']"]
# ['23056639', '2', '7', '5', '4.66E-06  ', "['Discovery', 'P-value']"]
# ['23056639', '2', '13', '7', '4.185E-01 ', "['Follow-up', 'P-value']"]
# ['23056639', '2', '6', '5', '7.84E-06  ', "['Discovery', 'P-value']"]
# ['23056639', '2', '6', '9', '1.89E-05  ', "['Combined', 'P-value']"]
# ['23056639', '2', '17', '7', '2.144E-01 ', "['Follow-up', 'P-value']"]
# ['23056639', '2', '19', '5', '2.11E-06  ', "['Discovery', 'P-value']"]
# ['23056639', '2', '16', '9', '1.50e-421 ', "['Combined', 'P-value']"]
# ['23056639', '2', '2', '9', '2.43E-02  ', "['Combined', 'P-value']"]
# ['23056639', '2', '10', '7', '9.482E-01 ', "['Follow-up', 'P-value']"]
# ['23056639', '2', '4', '8', '3.69E-02  ', "['Combined', 'Effect (se)', '-1.38E-02 (0.006)']"]
# ['23056639', '2', '8', '7', '3.651E-01 ', "['Follow-up', 'P-value']"]
# ['23056639', '2', '6', '4', '3.92E-02  ', "['Discovery', 'Effect (se)', '-4.79E-02 (0.011)']"]
# ['23056639', '2', '7', '6', '1.04E-02  ', "['Follow-up', 'Effect (se)']"]
# ['23056639', '2', '12', '9', '9.14E-04  ', "['Combined', 'P-value']"]
# ['23056639', '2', '13', '9', '5.97E-02  ', "['Combined', 'P-value']"]
# ['23056639', '2', '3', '7', '6.280E-01 ', "['Follow-up', 'P-value']"]
# ['23056639', '2', '17', '5', '1.65E-06  ', "['Discovery', 'P-value']"]
# ['23056639', '2', '12', '8', '2.10E-02  ', "['Combined', 'Effect (se)', '-1.38E-02 (0.006)']"]
# ['23056639', '2', '8', '4', '5.29E-02  ', "['Discovery', 'Effect (se)', '-4.79E-02 (0.011)']"]
# ['23056639', '2', '18', '7', '9.928E-01 ', "['Follow-up', 'P-value']"]
# ['23056639', '2', '3', '9', '1.77E-04  ', "['Combined', 'P-value']"]
# ['23056639', '2', '13', '6', '6.06E-03  ', "['Follow-up', 'Effect (se)']"]
# ['23056639', '2', '11', '9', '3.65E-47  ', "['Combined', 'P-value']"]
# ['23056639', '2', '5', '5', '1.37E-06  ', "['Discovery', 'P-value']"]
# ['23056639', '2', '2', '7', '6.218E-01 ', "['Follow-up', 'P-value']"]
# ['23056639', '2', '17', '8', '1.93E-02  ', "['Combined', 'Effect (se)', '-1.38E-02 (0.006)']"]
# ['23056639', '2', '9', '6', '1.10E-03  ', "['Follow-up', 'Effect (se)']"]
# ['23056639', '2', '4', '4', '1.12E-01  ', "['Discovery', 'Effect (se)', '-4.79E-02 (0.011)']"]
# ['23056639', '2', '2', '5', '5.36E-06  ', "['Discovery', 'P-value']"]
# ['23056639', '2', '4', '7', '8.215E-01 ', "['Follow-up', 'P-value']"]
# ['23056639', '2', '15', '5', '2.06E-187 ', "['Discovery', 'P-value']"]
# ['23056639', '2', '5', '4', '6.11E-02  ', "['Discovery', 'Effect (se)', '-4.79E-02 (0.011)']"]
# ['23056639', '2', '12', '5', '2.37E-06  ', "['Discovery', 'P-value']"]
# ['23056639', '2', '10', '8', '1.42E-02  ', "['Combined', 'Effect (se)', '-1.38E-02 (0.006)']"]
# ['23056639', '2', '7', '8', '2.09E-02  ', "['Combined', 'Effect (se)', '-1.38E-02 (0.006)']"]
# ['23056639', '2', '10', '5', '2.51E-06  ', "['Discovery', 'P-value']"]
# ['23056639', '2', '3', '6', '7.46E-03  ', "['Follow-up', 'Effect (se)']"]
# ['23056639', '2', '15', '7', '3.000E-223', "['Follow-up', 'P-value']"]
# ['23056639', '2', '7', '9', '1.86E-05  ', "['Combined', 'P-value']"]
# ['23056639', '2', '10', '9', '2.81E-02  ', "['Combined', 'P-value']"]
# ['23056639', '2', '18', '4', '4.60E-02  ', "['Discovery', 'Effect (se)', '-4.79E-02 (0.011)']"]
# ['23056639', '2', '3', '5', '1.47E-06  ', "['Discovery', 'P-value']"]
# ['23056639', '2', '9', '7', '8.639E-01 ', "['Follow-up', 'P-value']"]
# ['23056639', '2', '19', '6', '5.84E-03  ', "['Follow-up', 'Effect (se)']"]
# ['23056639', '2', '17', '6', '7.99E-03  ', "['Follow-up', 'Effect (se)']"]
# ['23056639', '2', '8', '5', '6.57E-06  ', "['Discovery', 'P-value']"]
# ['23056639', '2', '2', '6', '3.70E-03  ', "['Follow-up', 'Effect (se)']"]
# ['23056639', '2', '12', '4', '4.98E-02  ', "['Discovery', 'Effect (se)', '-4.79E-02 (0.011)']"]
# ['23056639', '2', '5', '6', '9.69E-03  ', "['Follow-up', 'Effect (se)']"]
# ['23056639', '2', '7', '7', '1.227E-01 ', "['Follow-up', 'P-value']"]
# ['23056639', '2', '15', '9', '4.97e-465 ', "['Combined', 'P-value']"]
# ['23056639', '2', '19', '9', '2.55E-02  ', "['Combined', 'P-value']"]
# ['23056639', '2', '8', '8', '1.67E-02  ', "['Combined', 'Effect (se)', '-1.38E-02 (0.006)']"]
# ['23056639', '2', '6', '6', '1.34E-02  ', "['Follow-up', 'Effect (se)']"]
# ['23056639', '2', '16', '7', '1.160E-202', "['Follow-up', 'P-value']"]
# ['23056639', '2', '14', '5', '2.35E-188 ', "['Discovery', 'P-value']"]
# ['23056639', '2', '10', '4', '6.43E-02  ', "['Discovery', 'Effect (se)', '-4.79E-02 (0.011)']"]
# ['23056639', '2', '7', '4', '3.26E-02  ', "['Discovery', 'Effect (se)', '-4.79E-02 (0.011)']"]
# ['23056639', '2', '8', '9', '2.67E-02  ', "['Combined', 'P-value']"]
# ['23056639', '2', '5', '7', '4.218E-01 ', "['Follow-up', 'P-value']"]
# ['23056639', '2', '4', '6', '3.75E-03  ', "['Follow-up', 'Effect (se)']"]
# ['23056639', '2', '16', '5', '3.48E-173 ', "['Discovery', 'P-value']"]
# ['23056639', '2', '17', '9', '5.89E-04  ', "['Combined', 'P-value']"]
# ['23056639', '2', '9', '5', '1.45E-06  ', "['Discovery', 'P-value']"]
# ['23056639', '2', '6', '7', '5.294E-02 ', "['Follow-up', 'P-value']"]
# ['23056639', '2', '17', '4', '5.54E-02  ', "['Discovery', 'Effect (se)', '-4.79E-02 (0.011)']"]
# ['23056639', '2', '11', '5', '4.52E-18  ', "['Discovery', 'P-value']"]
# ['23056639', '2', '4', '9', '7.61E-03  ', "['Combined', 'P-value']"]
# ['23056639', '2', '19', '7', '4.405E-01 ', "['Follow-up', 'P-value']"]
# ['23056639', '2', '18', '9', '9.52E-04  ', "['Combined', 'P-value']"]
# ['23056639', '2', '9', '9', '2.29E-02  ', "['Combined', 'P-value']"]
# ['23056639', '2', '18', '5', '1.94E-06  ', "['Discovery', 'P-value']"]
# ['23056639', '2', '14', '9', '2.35E-188 ', "['Combined', 'P-value']"]
# ['23056639', '2', '5', '9', '8.38E-05  ', "['Combined', 'P-value']"]
# ['23056639', '2', '12', '6', '4.55E-03  ', "['Follow-up', 'Effect (se)']"]
# ['23056639', '2', '4', '5', '7.79E-06  ', "['Discovery', 'P-value']"]
# ['23056639', '2', '12', '7', '5.655E-01 ', "['Follow-up', 'P-value']"]
# ['23056639', '2', '13', '5', '3.43E-06  ', "['Discovery', 'P-value']"]
# ['23886662', '3', '2', '6', '1.36E-07  ', "['P']"]
# ['23886662', '4', '16', '13', '7.95E-01  ', "['AD and asthma', 'P']"]
# ['23886662', '5', '52', '8', '9.20E-01  ', "['P']"]
# ['23886662', '5', '6', '8', '9.30E-01  ', "['P']"]
# ['23886662', '4', '10', '13', '4.30E-07  ', "['AD and asthma', 'P']"]
# ['23886662', '7', '20', '8', '7.02E-02  ', "['AD', 'P']"]
# ['23886662', '7', '2', '8', '8.12E-02  ', "['AD', 'P']"]
# ['23886662', '2', '5', '9', '9.80E-11  ', "['Replication', 'b', 'P']"]
# ['23886662', '4', '21', '8', '2.38E-01  ', "['AD all', 'P']"]
# ['23886662', '4', '6', '13', '2.10E-04  ', "['AD and asthma', 'P']"]
# ['23886662', '5', '47', '8', '1.70E-01  ', "['P']"]
# ['23886662', '3', '7', '14', '3.97E-02  ', "['UK and Ireland', 'P']"]
# ['23886662', '2', '4', '9', '2.49E-10  ', "['Replication', 'b', 'P']"]
# ['23886662', '7', '4', '13', '8.94E-01  ', "['AD and asthma', 'P', '1.53E', '-', '03']"]
# ['23886662', '2', '2', '9', '1.20E-07  ', "['Replication', 'b', 'P']"]
# ['23886662', '2', '15', '9', '1.66E-09  ', "['Replication', 'b', 'P']"]
# ['23886662', '5', '13', '8', '6.95E-01  ', "['P']"]
# ['23886662', '5', '44', '8', '1.26E-01  ', "['P']"]
# ['23886662', '7', '16', '8', '3.35E-01  ', "['AD', 'P']"]
# ['23886662', '4', '12', '13', '2.06E-01  ', "['AD and asthma', 'P']"]
# ['23886662', '3', '6', '20', '2.33E-03  ', "['Germany', 'P']"]
# ['23886662', '2', '2', '11', '8.95E-13  ', "['Combined', 'c', 'P']"]
# ['23886662', '5', '27', '8', '6.56E-01  ', "['P']"]
# ['23886662', '7', '19', '13', '6.43E-01  ', "['AD and asthma', 'P', '1.53E', '-', '03']"]
# ['23886662', '7', '20', '17', '4.13E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '5', '61', '8', '2.67E-01  ', "['P']"]
# ['23886662', '4', '6', '8', '1.73E-06  ', "['AD all', 'P']"]
# ['23886662', '3', '9', '20', '1.50E-01  ', "['Germany', 'P']"]
# ['23886662', '5', '10', '8', '3.75E-01  ', "['P']"]
# ['23886662', '7', '16', '17', '3.09E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '2', '6', '7', '1.79E-08  ', "['Screen', 'a', 'P']"]
# ['23886662', '3', '6', '7', '1.52E-03  ', "['Condition on', 'DRB_0701', '-']"]
# ['23886662', '4', '6', '17', '9.80E-05  ', "['AD not asthma', 'P']"]
# ['23886662', '5', '45', '8', '1.54E-01  ', "['P']"]
# ['23886662', '2', '8', '9', '3.00E-04  ', "['Replication', 'b', 'P']"]
# ['23886662', '3', '8', '6', '7.62E-04  ', "['P']"]
# ['23886662', '5', '24', '8', '8.86E-01  ', "['P']"]
# ['23886662', '3', '2', '20', '2.30E-05  ', "['Germany', 'P']"]
# ['23886662', '5', '29', '8', '8.55E-01  ', "['P']"]
# ['23886662', '4', '15', '13', '2.37E-01  ', "['AD and asthma', 'P']"]
# ['23886662', '2', '9', '7', '7.61E-06  ', "['Screen', 'a', 'P']"]
# ['23886662', '5', '43', '8', '2.77E-01  ', "['P']"]
# ['23886662', '2', '5', '11', '1.65E-17  ', "['Combined', 'c', 'P']"]
# ['23886662', '4', '5', '17', '9.28E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '4', '8', '13', '1.33E-01  ', "['AD and asthma', 'P']"]
# ['23886662', '3', '5', '7', '9.25E-03  ', "['Condition on', 'DRB_0701', '-']"]
# ['23886662', '7', '19', '17', '3.18E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '2', '10', '9', '5.32E-06  ', "['Replication', 'b', 'P']"]
# ['23886662', '2', '12', '11', '8.01E-12  ', "['Combined', 'c', 'P']"]
# ['23886662', '2', '9', '9', '5.81E-04  ', "['Replication', 'b', 'P']"]
# ['23886662', '4', '21', '17', '6.76E-02  ', "['AD not asthma', 'P']"]
# ['23886662', '5', '16', '8', '1.79E-08  ', "['P']"]
# ['23886662', '2', '15', '11', '1.61E-12  ', "['Combined', 'c', 'P']"]
# ['23886662', '7', '13', '17', '8.10E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '2', '8', '11', '4.33E-12  ', "['Combined', 'c', 'P']"]
# ['23886662', '5', '19', '8', '2.60E-01  ', "['P']"]
# ['23886662', '2', '10', '7', '5.56E-06  ', "['Screen', 'a', 'P']"]
# ['23886662', '4', '9', '17', '2.10E-02  ', "['AD not asthma', 'P']"]
# ['23886662', '5', '55', '8', '1.19E-02  ', "['P']"]
# ['23886662', '2', '12', '9', '8.96E-06  ', "['Replication', 'b', 'P']"]
# ['23886662', '4', '5', '8', '3.06E-01  ', "['AD all', 'P']"]
# ['23886662', '3', '4', '20', '1.21E-02  ', "['Germany', 'P']"]
# ['23886662', '7', '18', '17', '6.12E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '2', '15', '7', '8.17E-09  ', "['Screen', 'a', 'P']"]
# ['23886662', '7', '14', '17', '3.08E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '3', '6', '6', '9.60E-05  ', "['P']"]
# ['23886662', '3', '10', '6', '1.35E-03  ', "['P']"]
# ['23886662', '4', '17', '17', '6.22E-02  ', "['AD not asthma', 'P']"]
# ['23886662', '7', '9', '17', '2.91E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '7', '12', '13', '6.01E-02  ', "['AD and asthma', 'P', '1.53E', '-', '03']"]
# ['23886662', '2', '14', '7', '5.81E-07  ', "['Screen', 'a', 'P']"]
# ['23886662', '2', '12', '7', '3.81E-06  ', "['Screen', 'a', 'P']"]
# ['23886662', '3', '7', '6', '1.44E-04  ', "['P']"]
# ['23886662', '7', '7', '13', '4.02E-01  ', "['AD and asthma', 'P', '1.53E', '-', '03']"]
# ['23886662', '2', '13', '11', '2.96E-14  ', "['Combined', 'c', 'P']"]
# ['23886662', '4', '9', '13', '5.58E-03  ', "['AD and asthma', 'P']"]
# ['23886662', '7', '11', '13', '3.21E-01  ', "['AD and asthma', 'P', '1.53E', '-', '03']"]
# ['23886662', '4', '13', '13', '1.33E-03  ', "['AD and asthma', 'P']"]
# ['23886662', '2', '4', '11', '5.90E-11  ', "['Combined', 'c', 'P']"]
# ['23886662', '4', '4', '13', '6.87E-08  ', "['AD and asthma', 'P']"]
# ['23886662', '2', '4', '7', '2.65E-10  ', "['Screen', 'a', 'P']"]
# ['23886662', '4', '20', '17', '5.40E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '5', '12', '8', '6.95E-01  ', "['P']"]
# ['23886662', '4', '12', '8', '1.53E-01  ', "['AD all', 'P']"]
# ['23886662', '7', '13', '13', '5.10E-01  ', "['AD and asthma', 'P', '1.53E', '-', '03']"]
# ['23886662', '4', '18', '8', '6.73E-01  ', "['AD all', 'P']"]
# ['23886662', '3', '10', '14', '5.02E-03  ', "['UK and Ireland', 'P']"]
# ['23886662', '5', '58', '8', '6.95E-01  ', "['P']"]
# ['23886662', '7', '21', '17', '2.20E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '3', '7', '20', '8.08E-04  ', "['Germany', 'P']"]
# ['23886662', '3', '5', '20', '8.28E-03  ', "['Germany', 'P']"]
# ['23886662', '4', '3', '17', '4.72E-12  ', "['AD not asthma', 'P']"]
# ['23886662', '4', '8', '8', '3.06E-02  ', "['AD all', 'P']"]
# ['23886662', '7', '10', '17', '3.44E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '3', '2', '14', '8.29E-04  ', "['UK and Ireland', 'P']"]
# ['23886662', '2', '6', '11', '1.93E-14  ', "['Combined', 'c', 'P']"]
# ['23886662', '2', '8', '7', '5.64E-06  ', "['Screen', 'a', 'P']"]
# ['23886662', '2', '13', '9', '1.46E-06  ', "['Replication', 'b', 'P']"]
# ['23886662', '7', '7', '17', '3.79E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '2', '2', '7', '1.27E-06  ', "['Screen', 'a', 'P']"]
# ['23886662', '4', '4', '17', '5.03E-06  ', "['AD not asthma', 'P']"]
# ['23886662', '5', '49', '8', '3.35E-02  ', "['P']"]
# ['23886662', '4', '13', '8', '1.18E-04  ', "['AD all', 'P']"]
# ['23886662', '3', '5', '14', '2.06E-03  ', "['UK and Ireland', 'P']"]
# ['23886662', '5', '40', '8', '5.58E-02  ', "['P']"]
# ['23886662', '4', '20', '8', '6.68E-01  ', "['AD all', 'P']"]
# ['23886662', '5', '38', '8', '3.17E-01  ', "['P']"]
# ['23886662', '5', '50', '8', '5.65E-01  ', "['P']"]
# ['23886662', '5', '48', '8', '1.70E-01  ', "['P']"]
# ['23886662', '5', '14', '8', '6.66E-01  ', "['P']"]
# ['23886662', '4', '7', '13', '5.65E-02  ', "['AD and asthma', 'P']"]
# ['23886662', '3', '10', '20', '7.68E-02  ', "['Germany', 'P']"]
# ['23886662', '4', '21', '13', '9.84E-01  ', "['AD and asthma', 'P']"]
# ['23886662', '4', '14', '8', '5.29E-02  ', "['AD all', 'P']"]
# ['23886662', '5', '11', '8', '4.11E-01  ', "['P']"]
# ['23886662', '5', '39', '8', '8.69E-01  ', "['P']"]
# ['23886662', '5', '62', '8', '8.32E-01  ', "['P']"]
# ['23886662', '4', '10', '17', '4.00E-06  ', "['AD not asthma', 'P']"]
# ['23886662', '4', '9', '8', '1.18E-03  ', "['AD all', 'P']"]
# ['23886662', '3', '4', '14', '9.62E-04  ', "['UK and Ireland', 'P']"]
# ['23886662', '2', '10', '11', '1.33E-10  ', "['Combined', 'c', 'P']"]
# ['23886662', '5', '3', '8', '1.69E-01  ', "['P']"]
# ['23886662', '7', '7', '8', '3.02E-01  ', "['AD', 'P']"]
# ['23886662', '4', '17', '13', '1.05E-01  ', "['AD and asthma', 'P']"]
# ['23886662', '5', '15', '8', '9.97E-01  ', "['P']"]
# ['23886662', '2', '6', '9', '1.56E-06  ', "['Replication', 'b', 'P']"]
# ['23886662', '7', '2', '17', '9.28E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '4', '8', '17', '6.65E-02  ', "['AD not asthma', 'P']"]
# ['23886662', '5', '37', '8', '2.17E-01  ', "['P']"]
# ['23886662', '4', '7', '8', '4.46E-01  ', "['AD all', 'P']"]
# ['23886662', '5', '26', '8', '6.57E-02  ', "['P']"]
# ['23886662', '5', '20', '8', '2.05E-02  ', "['P']"]
# ['23886662', '5', '25', '8', '6.57E-02  ', "['P']"]
# ['23886662', '3', '5', '6', '6.08E-05  ', "['P']"]
# ['23886662', '5', '9', '8', '8.85E-02  ', "['P']"]
# ['23886662', '7', '5', '13', '1.28E-01  ', "['AD and asthma', 'P', '1.53E', '-', '03']"]
# ['23886662', '4', '20', '13', '1.08E-01  ', "['AD and asthma', 'P']"]
# ['23886662', '5', '54', '8', '2.44E-01  ', "['P']"]
# ['23886662', '5', '60', '8', '2.47E-01  ', "['P']"]
# ['23886662', '2', '5', '7', '2.66E-08  ', "['Screen', 'a', 'P']"]
# ['23886662', '5', '4', '8', '6.98E-01  ', "['P']"]
# ['23886662', '4', '12', '17', '1.96E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '7', '8', '17', '2.46E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '2', '7', '9', '1.09E-04  ', "['Replication', 'b', 'P']"]
# ['23886662', '7', '15', '17', '2.81E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '4', '19', '17', '4.78E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '5', '28', '8', '4.40E-03  ', "['P']"]
# ['23886662', '4', '15', '8', '3.13E-03  ', "['AD all', 'P']"]
# ['23886662', '3', '6', '14', '5.14E-03  ', "['UK and Ireland', 'P']"]
# ['23886662', '4', '3', '8', '1.88E-16  ', "['AD all', 'P']"]
# ['23886662', '5', '22', '8', '1.43E-02  ', "['P']"]
# ['23886662', '5', '42', '8', '2.11E-01  ', "['P']"]
# ['23886662', '5', '31', '8', '3.32E-01  ', "['P']"]
# ['23886662', '7', '11', '17', '2.11E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '4', '14', '13', '2.83E-01  ', "['AD and asthma', 'P']"]
# ['23886662', '2', '9', '11', '3.19E-08  ', "['Combined', 'c', 'P']"]
# ['23886662', '4', '11', '13', '1.13E-03  ', "['AD and asthma', 'P']"]
# ['23886662', '7', '16', '13', '7.37E-01  ', "['AD and asthma', 'P', '1.53E', '-', '03']"]
# ['23886662', '7', '18', '8', '4.44E-01  ', "['AD', 'P']"]
# ['23886662', '4', '7', '17', '8.67E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '4', '14', '17', '8.34E-02  ', "['AD not asthma', 'P']"]
# ['23886662', '7', '19', '8', '6.81E-01  ', "['AD', 'P']"]
# ['23886662', '4', '10', '8', '3.91E-10  ', "['AD all', 'P']"]
# ['23886662', '2', '7', '11', '1.28E-09  ', "['Combined', 'c', 'P']"]
# ['23886662', '5', '32', '8', '3.10E-02  ', "['P']"]
# ['23886662', '4', '16', '8', '4.67E-01  ', "['AD all', 'P']"]
# ['23886662', '2', '11', '11', '5.78E-10  ', "['Combined', 'c', 'P']"]
# ['23886662', '3', '3', '20', '2.96E-04  ', "['Germany', 'P']"]
# ['23886662', '7', '11', '8', '6.51E-01  ', "['AD', 'P']"]
# ['23886662', '5', '34', '8', '4.05E-02  ', "['P']"]
# ['23886662', '3', '3', '14', '4.16E-03  ', "['UK and Ireland', 'P']"]
# ['23886662', '4', '4', '8', '8.67E-11  ', "['AD all', 'P']"]
# ['23886662', '7', '13', '8', '6.14E-01  ', "['AD', 'P']"]
# ['23886662', '2', '11', '9', '1.56E-05  ', "['Replication', 'b', 'P']"]
# ['23886662', '5', '57', '8', '9.30E-01  ', "['P']"]
# ['23886662', '3', '8', '14', '3.94E-02  ', "['UK and Ireland', 'P']"]
# ['23886662', '5', '53', '8', '3.10E-01  ', "['P']"]
# ['23886662', '2', '13', '7', '9.46E-07  ', "['Screen', 'a', 'P']"]
# ['23886662', '5', '18', '8', '9.55E-01  ', "['P']"]
# ['23886662', '2', '14', '11', '4.49E-13  ', "['Combined', 'c', 'P']"]
# ['23886662', '5', '1', '8', '2.30E-02  ', "['P']"]
# ['23886662', '2', '7', '7', '2.65E-06  ', "['Screen', 'a', 'P']"]
# ['23886662', '3', '4', '7', '5.21E-03  ', "['Condition on', 'DRB_0701', '-']"]
# ['23886662', '5', '35', '8', '1.05E-01  ', "['P']"]
# ['23886662', '4', '11', '8', '2.77E-05  ', "['AD all', 'P']"]
# ['23886662', '4', '2', '8', '2.38E-09  ', "['AD all', 'P']"]
# ['23886662', '2', '3', '9', '3.42E-09  ', "['Replication', 'b', 'P']"]
# ['23886662', '3', '9', '6', '1.26E-03  ', "['P']"]
# ['23886662', '7', '15', '8', '8.20E-01  ', "['AD', 'P']"]
# ['23886662', '4', '2', '13', '7.21E-09  ', "['AD and asthma', 'P']"]
# ['23886662', '3', '3', '6', '6.03E-06  ', "['P']"]
# ['23886662', '4', '3', '13', '2.96E-13  ', "['AD and asthma', 'P']"]
# ['23886662', '3', '9', '14', '3.67E-03  ', "['UK and Ireland', 'P']"]
# ['23886662', '4', '17', '8', '2.98E-02  ', "['AD all', 'P']"]
# ['23886662', '5', '8', '8', '9.45E-01  ', "['P']"]
# ['23886662', '4', '19', '8', '1.84E-01  ', "['AD all', 'P']"]
# ['23886662', '5', '2', '8', '3.65E-02  ', "['P']"]
# ['23886662', '3', '4', '6', '3.82E-05  ', "['P']"]
# ['23886662', '4', '18', '13', '8.64E-01  ', "['AD and asthma', 'P']"]
# ['23886662', '2', '11', '7', '6.35E-06  ', "['Screen', 'a', 'P']"]
# ['23886662', '2', '3', '7', '7.27E-07  ', "['Screen', 'a', 'P']"]
# ['23886662', '5', '21', '8', '1.70E-02  ', "['P']"]
# ['23886662', '4', '15', '17', '4.63E-04  ', "['AD not asthma', 'P']"]
# ['23886662', '5', '36', '8', '1.30E-01  ', "['P']"]
# ['23886662', '7', '15', '13', '3.86E-01  ', "['AD and asthma', 'P', '1.53E', '-', '03']"]
# ['23886662', '4', '11', '17', '3.73E-03  ', "['AD not asthma', 'P']"]
# ['23886662', '4', '5', '13', '5.00E-02  ', "['AD and asthma', 'P']"]
# ['23886662', '7', '12', '17', '6.08E-02  ', "['AD not asthma', 'P']"]
# ['23886662', '4', '18', '17', '6.52E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '5', '17', '8', '4.94E-09  ', "['P']"]
# ['23886662', '3', '8', '20', '2.42E-03  ', "['Germany', 'P']"]
# ['23886662', '5', '51', '8', '3.46E-01  ', "['P']"]
# ['23886662', '5', '7', '8', '9.40E-01  ', "['P']"]
# ['23886662', '4', '2', '17', '1.09E-05  ', "['AD not asthma', 'P']"]
# ['23886662', '5', '33', '8', '3.34E-01  ', "['P']"]
# ['23886662', '5', '41', '8', '9.33E-01  ', "['P']"]
# ['23886662', '2', '3', '11', '2.11E-15  ', "['Combined', 'c', 'P']"]
# ['23886662', '5', '56', '8', '4.75E-03  ', "['P']"]
# ['23886662', '4', '13', '17', '5.97E-03  ', "['AD not asthma', 'P']"]
# ['23886662', '5', '30', '8', '3.17E-01  ', "['P']"]
# ['23886662', '4', '16', '17', '1.78E-01  ', "['AD not asthma', 'P']"]
# ['23886662', '2', '14', '9', '7.44E-05  ', "['Replication', 'b', 'P']"]
# ['23886662', '5', '59', '8', '8.77E-01  ', "['P']"]
# ['23886662', '4', '19', '13', '1.47E-01  ', "['AD and asthma', 'P']"]
# ['23886662', '5', '5', '8', '2.07E-01  ', "['P']"]
# ['23886662', '7', '4', '8', '1.48E-01  ', "['AD', 'P']"]
# ['25188341', '3', '2', '11', '4.00E-02  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '3', '14', '11', '3.10E-01  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '3', '7', '11', '1.30E-04  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '3', '13', '14', '1.00E-01  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '2', '4', '11', '2.00E-08  ', "['Pval']"]
# ['25188341', '3', '4', '11', '1.60E-01  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '3', '6', '11', '4.70E-03  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '3', '9', '8', '1.1E-15   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '3', '17', '14', '6.60E-03  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '3', '19', '11', '1.80E-02  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '3', '17', '11', '1.10E-03  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '2', '6', '11', '4.83E-44  ', "['Pval']"]
# ['25188341', '2', '12', '11', '1.10E-12  ', "['Pval']"]
# ['25188341', '3', '21', '11', '8.50E-02  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '3', '9', '14', '1.00E-02  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '3', '7', '8', '6.1E-16   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '3', '16', '11', '8.40E-01  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '3', '15', '14', '8.40E-01  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '3', '2', '8', '5.7E-24   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '3', '8', '11', '1.30E-04  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '3', '21', '14', '6.90E-02  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '3', '3', '14', '2.50E-04  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '2', '2', '11', '1.90E-08  ', "['Pval']"]
# ['25188341', '3', '15', '8', '1.0E-04   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '2', '16', '11', '2.92E-21  ', "['Pval']"]
# ['25188341', '3', '14', '8', '5.5E-09   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '3', '4', '14', '3.80E-01  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '2', '10', '11', '8.00E-09  ', "['Pval']"]
# ['25188341', '3', '21', '8', '7.9E-09   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '2', '13', '11', '2.83E-11  ', "['Pval']"]
# ['25188341', '3', '6', '14', '4.20E-02  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '3', '11', '8', '2.9E-12   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '2', '5', '11', '4.73E-47  ', "['Pval']"]
# ['25188341', '3', '19', '14', '6.10E-02  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '3', '22', '14', '1.10E-02  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '3', '5', '14', '9.10E-02  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '3', '8', '8', '9.3E-26   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '3', '12', '14', '2.30E-01  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '3', '13', '8', '9.7E-15   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '3', '10', '11', '1.60E-02  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '3', '18', '11', '5.50E-01  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '3', '20', '8', '1.1E-08   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '3', '18', '8', '4.8E-09   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '3', '5', '11', '7.30E-02  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '3', '3', '11', '3.40E-06  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '3', '16', '14', '8.40E-01  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '3', '3', '8', '6.9E-44   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '3', '8', '14', '1.70E-03  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '3', '20', '14', '8.80E-01  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '3', '4', '8', '5.2E-11   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '3', '2', '14', '9.80E-01  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '2', '8', '11', '1.78E-27  ', "['Pval']"]
# ['25188341', '2', '15', '11', '4.60E-08  ', "['Pval']"]
# ['25188341', '3', '9', '11', '1.40E-02  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '3', '19', '8', '5.6E-10   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '3', '14', '14', '7.20E-01  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '3', '18', '14', '4.70E-01  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '3', '5', '8', '1.1E-13   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '2', '14', '11', '4.87E-12  ', "['Pval']"]
# ['25188341', '2', '3', '11', '3.48E-38  ', "['Pval']"]
# ['25188341', '3', '20', '11', '6.20E-01  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '3', '10', '8', '3.0E-06   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '3', '22', '11', '3.30E-03  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '3', '16', '8', '3.2E-08   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '3', '6', '8', '2.8E-25   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '2', '1', '11', '2.02E-62  ', "['Pval']"]
# ['25188341', '3', '10', '14', '2.60E-02  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '3', '12', '8', '7.4E-14   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '2', '11', '11', '4.30E-08  ', "['Pval']"]
# ['25188341', '2', '7', '11', '3.14E-47  ', "['Pval']"]
# ['25188341', '3', '7', '14', '3.60E-02  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '3', '13', '11', '4.30E-03  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '3', '17', '8', '3.2E-08   ', "['IGAP Paper', '*', 'p-value']"]
# ['25188341', '3', '11', '14', '3.40E-01  ', "['Complete Analysis', 'p-value']"]
# ['25188341', '3', '11', '11', '5.90E-01  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '3', '12', '11', '4.60E-02  ', "['Primary Analysis', 'p-value']"]
# ['25188341', '2', '9', '11', '6.00E-09  ', "['Pval']"]
# ['25188341', '3', '22', '8', '2.5E-08   ', "['IGAP Paper', '*', 'p-value']"]

# %% [markdown]
# We express several of these simple patterns below as a set of labeling functions:
